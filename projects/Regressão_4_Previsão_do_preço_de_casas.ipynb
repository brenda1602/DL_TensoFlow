# %% [markdown]
# <a href="https://colab.research.google.com/github/brenda1602/DL_TensorFlow/blob/master/Regress%C3%A3o_4_Previs%C3%A3o_do_pre%C3%A7o_de_casas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Previsão no preço de casas

# %% [markdown]
# ##1. Biblioteca e dados

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
tf.__version__
# Out:
# '2.2.0'

# %%
house= pd.read_csv('/content/kc-house-data.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# ##2. Limpeza dos dados

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house.corr(), annot = True);

# %%
house.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
selected= [ 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement' ]

# %%
X= house[selected]

# %%
X.shape
# Out:
# (21613, 7)

# %%
sns.pairplot(X)

# %%
Y=house['price'];

# %%
Y.shape
# Out:
# (21613,)

# %% [markdown]
# ###dividir a base de dado em teste e treinamento

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
Y = Y.values.reshape(-1,1)

# %%
Y_scaled = scaler.fit_transform(Y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X_scaled,Y_scaled,test_size=0.25)

# %% [markdown]
# ## Criação do modelo

# %%
model= tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(7, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 21,101
# Trainable params: 21,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, Y_train, epochs = 100, batch_size = 50, validation_split=0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.9114e-04
# Epoch 3/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 9.8843e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 6/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 9.8464e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 9/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.9022e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.9324e-04
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.9699e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9508e-04 - val_loss: 0.0011
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 14/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.5794e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9261e-04 - val_loss: 9.7378e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9580e-04 - val_loss: 9.8067e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.6628e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7605e-04 - val_loss: 9.6292e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7628e-04 - val_loss: 9.5528e-04
# Epoch 20/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8245e-04 - val_loss: 9.7923e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6430e-04 - val_loss: 9.6793e-04
# Epoch 22/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7706e-04 - val_loss: 9.6701e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8580e-04 - val_loss: 9.6365e-04
# Epoch 24/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6417e-04 - val_loss: 9.6640e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8171e-04 - val_loss: 9.4712e-04
# Epoch 26/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6356e-04 - val_loss: 0.0010
# Epoch 27/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6539e-04 - val_loss: 9.5889e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6493e-04 - val_loss: 9.7199e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6602e-04 - val_loss: 9.6251e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7532e-04 - val_loss: 9.5911e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6961e-04 - val_loss: 9.7073e-04
# Epoch 32/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5732e-04 - val_loss: 9.6811e-04
# Epoch 33/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5561e-04 - val_loss: 9.6823e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.
100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9750e-04 - val_loss: 9.9831e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9617e-04 - val_loss: 9.4726e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9547e-04 - val_loss: 9.7302e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8972e-04 - val_loss: 9.6712e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2010e-04 - val_loss: 9.4539e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8612e-04 - val_loss: 9.5137e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9619e-04 - val_loss: 9.5461e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7766e-04 - val_loss: 9.7061e-04
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8228e-04 - val_loss: 9.8510e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0397e-04 - val_loss: 0.0010
# Epoch 96/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8284e-04 - val_loss: 9.5011e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8093e-04 - val_loss: 0.0011
# Epoch 98/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0164e-04 - val_loss: 9.4550e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8560e-04 - val_loss: 9.4164e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0039e-04 - val_loss: 9.6409e-04

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss']);

# %% [markdown]
# ##Teste do modelo

# %% [markdown]
#  'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement'

# %%
X_teste_1=np.array([[4, 3, 1960, 5000, 1, 2000, 3000]])

# %%
scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_teste_1)

# %%
Y_predict_1= model.predict(X_test_scaled_1)

# %%
Y_predict_1 = scaler.inverse_transform(Y_predict_1)
Y_predict_1
# Out:
# array([[177012.52]], dtype=float32)

# %%
Y_predict = model.predict(X_test)
plt.plot(Y_test, Y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values');

# %% [markdown]
# ### Calcular o erro

# %%
y_predict_orig=scaler.inverse_transform(Y_predict)
y_test_orig= scaler.inverse_transform(Y_test)
n=len(X_test)
k=(X_test.shape[1])
n
# Out:
# 5404

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE= float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)), '.3f'))
MSE= mean_squared_error(y_test_orig,y_predict_orig)
MAE=mean_absolute_error(y_test_orig, y_predict_orig)
r2= r2_score(y_test_orig, y_predict_orig)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)
print(r2, adj_r2)
# Out:
# 0.5691579859975223 0.5685990730809142

# %% [markdown]
# ##Aumentar as caracteristicas
# ###Para diminuir o erro

# %%
selected= [ 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement','waterfront', 'view','condition','grade', 'sqft_above', 'yr_built', 'yr_renovated','zipcode','lat','long','sqft_living15', 'sqft_lot15']

# %%
X_2=house[selected]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
X_scaled_2=scaler.fit_transform(X_2)

# %%
Y_2=house['price']

# %%
Y_2 = Y_2.values.reshape(-1,1)
Y_scaled_2 = scaler.fit_transform(Y_2)

# %%
from sklearn.model_selection import train_test_split
X_train_2, X_test_2, Y_train_2,Y_test_2=train_test_split(X_scaled_2,Y_scaled_2,test_size=0.25)

# %%
X_train_2.shape
# Out:
# (16209, 19)

# %%
model= tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(19, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist=model.fit(X_train_2,Y_train_2, epochs=100,batch_size=50, validation_split=0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.2812e-04 - val_loss: 3.0383e-04
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.1931e-04 - val_loss: 2.9276e-04
# Epoch 3/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4366e-04 - val_loss: 2.9754e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4952e-04 - val_loss: 3.1303e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3386e-04 - val_loss: 2.9823e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.1909e-04 - val_loss: 3.0972e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.2684e-04 - val_loss: 3.0986e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1
100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.0735e-04 - val_loss: 3.4114e-04
# Epoch 60/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9364e-05 - val_loss: 3.2436e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7957e-05 - val_loss: 3.1570e-04
# Epoch 62/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8808e-05 - val_loss: 3.1309e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.0220e-04 - val_loss: 2.9919e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7678e-05 - val_loss: 3.3462e-04
# Epoch 65/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9371e-05 - val_loss: 3.5340e-04
# Epoch 66/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.1194e-04 - val_loss: 3.2128e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7216e-05 - val_loss: 3.0681e-04
# Epoch 68/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6635e-05 - val_loss: 3.4336e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6845e-05 - val_loss: 3.4162e-04
# Epoch 70/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8057e-05 - val_loss: 3.2281e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4230e-05 - val_loss: 3.6347e-04
# Epoch 72/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4095e-05 - val_loss: 3.3823e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6582e-05 - val_loss: 3.0850e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.0192e-04 - val_loss: 3.3558e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1002e-05 - val_loss: 3.3002e-04
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9912e-05 - val_loss: 3.2113e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0703e-05 - val_loss: 3.0397e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2868e-05 - val_loss: 3.3615e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5766e-05 - val_loss: 3.3354e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7876e-05 - val_loss: 3.3193e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4423e-05 - val_loss: 3.1551e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4842e-05 - val_loss: 3.2365e-04
# Epoch 83/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2739e-05 - val_loss: 3.2040e-04
# Epoch 84/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1965e-05 - val_loss: 3.2712e-04
# Epoch 85/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3768e-05 - val_loss: 3.1202e-04
# Epoch 86/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9153e-05 - val_loss: 3.1875e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6711e-05 - val_loss: 3.2611e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0481e-05 - val_loss: 3.0907e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7377e-05 - val_loss: 3.0650e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8716e-05 - val_loss: 2.9930e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2697e-05 - val_loss: 3.3058e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.4016e-05 - val_loss: 3.1896e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2550e-05 - val_loss: 3.2865e-04
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8589e-05 - val_loss: 3.6908e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1325e-05 - val_loss: 3.0998e-04
# Epoch 96/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8999e-05 - val_loss: 3.3563e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0962e-05 - val_loss: 3.3577e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7944e-05 - val_loss: 3.2179e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2974e-05 - val_loss: 3.3286e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7791e-05 - val_loss: 3.3371e-04

# %%
Y_predict_2 = model.predict(X_test_2)

# %%
y_predict_orig_2=scaler.inverse_transform(Y_predict_2)
y_test_orig_2= scaler.inverse_transform(Y_test_2)
n=len(X_test)
k=(X_test.shape[1])
n
# Out:
# 5404

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE= float(format(np.sqrt(mean_squared_error(y_test_orig_2, y_predict_orig_2)), '.3f'))
MSE= mean_squared_error(y_test_orig_2,y_predict_orig_2)
MAE=mean_absolute_error(y_test_orig_2, y_predict_orig_2)
r2= r2_score(y_test_orig_2, y_predict_orig_2)
adj_r2=1-(1-r2)*(n-1)/(n-k-1)
print(r2, adj_r2)
# Out:
# 0.8457339487383254 0.8455338259883566
